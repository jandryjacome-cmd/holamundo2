# %% [markdown]
# <a href="https://colab.research.google.com/github/jandryjacome-cmd/holamundo2/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ejercicios de lenguajes de porgramacion **bold text**

# %% [markdown]
# hola mundo en python

# %% [markdown]
# Famoso por ser fácil de leer y aprender. Es el lenguaje líder en Inteligencia Artificial y ciencia de datos.

# %%
print("HOLA MUNDO ")

# %% [markdown]
# hola mundo en JavaScript

# %% [markdown]
# Es el lenguaje fundamental de la web. Se destaca por ser conciso y no requiere de una estructura compleja para tareas simples.

# %%
console.log("Hola Mundo");

# %% [markdown]
# ### hola mundo en C++

# %% [markdown]
# Un lenguaje compilado de alto rendimiento. A diferencia de Python o JavaScript, aquí necesitas definir una función principal (main) y llamar a librerías específicas para la entrada/salida de datos.

# %%
#include <iostream>

int main() {
    std::cout << "Hola Mundo" << std::endl;
    return 0;
}

# %% [markdown]
# hola mundo en java

# %% [markdown]
# Muy utilizado en entornos empresariales y aplicaciones Android. Java es famoso por ser "verboso" (requiere escribir más código), ya que todo debe estar contenido dentro de una clase.

# %%
public class Principal {
    public static void main(String[] args) {
        System.out.println("Hola Mundo");
    }
}
